# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
N = 1000
D = 50
Sigma = np.identity(D)
mu1 = np.zeros(D)
mu2 = np.zeros(D)

mu1[0:10]  = -1.0
mu1[10:20] = 1.0

x1 = np.random.multivariate_normal(mu1, Sigma, size=N/2)
x2 = np.random.multivariate_normal(mu2, Sigma, size=N/2)

plt.plot(x1[:,0], x1[:,1], 'bx');
plt.plot(x2[:,0], x2[:,1], 'rx');

# %%
x = np.concatenate([x1,x2], axis=0)
y = np.concatenate([np.repeat(0, N/2), np.repeat(1, N/2)], axis=0)

# %%
import pystan
model_code = """
data {
    int<lower=0> N;
    int<lower=1> D;

    int<lower=0, upper=1> y[N];
    vector[D] x[N];
}

parameters {
    matrix[1,D] beta;
    real alpha;
}

model {
    to_vector(beta) ~ normal(0,5);
    alpha ~ normal(0, 5);

    for (n in 1:N)
        y[n] ~ bernoulli_logit(beta * x[n] + alpha);
}
"""
model = pystan.StanModel(model_code=model_code)

# %%
fit = model.sampling(data=dict(N=N, D=D, x=x, y=y))
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/multiprocessing/queues.py:392: UserWarning: Pickling fit objects is an experimental feature!
# The relevant StanModel instance must be pickled along with this fit object.
# When unpickling the StanModel must be unpickled first.
#   return send(obj)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/multiprocessing/queues.py:392: UserWarning: Pickling fit objects is an experimental feature!
# The relevant StanModel instance must be pickled along with this fit object.
# When unpickling the StanModel must be unpickled first.
#   return send(obj)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/multiprocessing/queues.py:392: UserWarning: Pickling fit objects is an experimental feature!
# The relevant StanModel instance must be pickled along with this fit object.
# When unpickling the StanModel must be unpickled first.
#   return send(obj)
# ...

# %%
print fit
# Out:
# Inference for Stan model: anon_model_0abae58ed70376355461e557ba44340e.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#              mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# beta[0,0]    1.93    0.02   0.79   0.49    1.4    1.9   2.44   3.55 1027.0    1.0
# beta[0,1]    2.89    0.03   0.84   1.28   2.32   2.86   3.44   4.61  965.0    1.0
# beta[0,2]    2.94    0.03   0.87   1.33   2.35   2.93   3.53   4.65  997.0    1.0
# beta[0,3]    3.05    0.03   0.95   1.27   2.39   3.03   3.64   5.02 1009.0    1.0
# beta[0,4]    2.57    0.03   0.84    1.0   1.98   2.53   3.12   4.27 1033.0    1.0
# beta[0,5]    4.04    0.03   0.99   2.14   3.36   4.02   4.68   6.03  830.0    1.0
# beta[0,6]     1.8    0.02   0.75   0.34   1.29   1.81   2.29   3.33 1033.0    1.0
# beta[0,7]    3.34    0.03   0.86    1.7   2.73   3.32    3.9   5.09  869.0    1.0
# ...

# %%
samples = fit.extract()

# %%
alpha = samples['alpha']
beta  = samples['beta'].squeeze()

def logistic_plot(alpha, beta):
    xx = np.linspace(-5, 5)
    yy = np.linspace(-5, 5)
    xv, yv = np.meshgrid(xx, yy)

    nu = (beta[0] * xv) + (beta[1] * yv) + alpha
    z = 1 / (1 + np.exp(-nu))

    plt.plot(x1[:,0], x1[:,1], 'bx')
    plt.plot(x2[:,0], x2[:,1], 'rx')
    plt.contourf(xx, yy, nu)

logistic_plot(alpha.mean(), beta.mean(axis=0))

# %%
n = np.random.randint(len(alpha))
alpha_p = alpha[n]
beta_p  = beta[n]
logistic_plot(alpha_p, beta_p)

# %%
plt.hist(beta[:,0]);

# %%
beta.shape
# Out:
# (4000, 50)

# %%
samples['beta'].squeeze().shape
# Out:
# (4000, 50)

# %%
opt = model.optimizing(data=dict(N=N, D=D, x=x, y=y))

# %%
print opt['alpha']
plt.plot(opt['beta'].squeeze());
# Out:
# 15.7840511502
