# %%
import numpy as np
import scipy.special
import scipy.stats

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def generate_data(N, D):
    np.random.seed(1)
    x = np.random.multivariate_normal(np.zeros(D), np.identity(D), size=N)
    beta = np.zeros(D)
#     beta[0] = 1
#     beta[1] = -1
    beta[0:10] = 1
    beta[10:20] = -1
    alpha = 0
    p = scipy.special.expit(x.dot(beta) + alpha)
    r = np.random.uniform(size=N)
    category = r < p
    return x, category

N = 1000
D = 50
x, category = generate_data(N, D)
x[-1] = 1.
y = np.array(category, dtype=int)
x0 = x[category]
x1 = x[np.logical_not(category)]

plt.plot(x0[:,0], x0[:,1], 'rx');
plt.plot(x1[:,0], x1[:,1], 'bx');

# %%
import pystan
model_code = """
data {
    int<lower=0> N;
    int<lower=1> D;

    int<lower=0, upper=1> y[N];
    vector[D] x[N];
}

parameters {
    matrix[1,D] beta;
    real alpha;
}

model {
    to_vector(beta) ~ normal(0,5);
    alpha ~ normal(0, 5);

    for (n in 1:N)
        y[n] ~ bernoulli_logit(beta * x[n] + alpha);
}
"""
model = pystan.StanModel(model_code=model_code)

# %%
fit = model.sampling(data=dict(N=N, D=D, x=x, y=y))
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/multiprocessing/queues.py:392: UserWarning: Pickling fit objects is an experimental feature!
# The relevant StanModel instance must be pickled along with this fit object.
# When unpickling the StanModel must be unpickled first.
#   return send(obj)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/multiprocessing/queues.py:392: UserWarning: Pickling fit objects is an experimental feature!
# The relevant StanModel instance must be pickled along with this fit object.
# When unpickling the StanModel must be unpickled first.
#   return send(obj)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/multiprocessing/queues.py:392: UserWarning: Pickling fit objects is an experimental feature!
# The relevant StanModel instance must be pickled along with this fit object.
# When unpickling the StanModel must be unpickled first.
#   return send(obj)
# ...

# %%
print fit
# Out:
# Inference for Stan model: anon_model_0abae58ed70376355461e557ba44340e.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#              mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# beta[0,0]    1.22  5.2e-3   0.15   0.94   1.12   1.22   1.32   1.53  858.0    1.0
# beta[0,1]    1.06  4.8e-3   0.15   0.77   0.96   1.06   1.17   1.36  993.0    1.0
# beta[0,2]    1.28  5.4e-3   0.16   0.98   1.18   1.28   1.39    1.6  843.0    1.0
# beta[0,3]    1.28  5.0e-3   0.15    1.0   1.18   1.27   1.38   1.58  845.0    1.0
# beta[0,4]     1.3  5.3e-3   0.15   1.01    1.2    1.3    1.4   1.63  850.0    1.0
# beta[0,5]    1.17  4.9e-3   0.15   0.88   1.06   1.17   1.27   1.46  948.0    1.0
# beta[0,6]    1.13  4.9e-3   0.15   0.85   1.03   1.13   1.23   1.43  934.0    1.0
# beta[0,7]    1.17  5.0e-3   0.15   0.88   1.06   1.16   1.26   1.47  940.0    1.0
# ...

# %%
samples = fit.extract()

# %%
alpha = samples['alpha']
beta  = samples['beta'].squeeze()

def logistic_plot(alpha, beta):
    xx = np.linspace(-5, 5)
    yy = np.linspace(-5, 5)
    xv, yv = np.meshgrid(xx, yy)

    nu = (beta[0] * xv) + (beta[1] * yv) + alpha
    z = 1 / (1 + np.exp(-nu))

    plt.plot(x1[:,0], x1[:,1], 'bx')
    plt.plot(x2[:,0], x2[:,1], 'rx')
    plt.contourf(xx, yy, nu)

logistic_plot(alpha.mean(), beta.mean(axis=0))

# %%
n = np.random.randint(len(alpha))
alpha_p = alpha[n]
beta_p  = beta[n]
logistic_plot(alpha_p, beta_p)

# %%
plt.hist(beta[:,0]);

# %%
opt = model.optimizing(data=dict(N=N, D=D, x=x, y=y))

# %%
print opt['alpha']
plt.plot(opt['beta'].squeeze());
# Out:
# -0.190353750113

# %%
beta = samples['beta'].mean(axis=0).squeeze()
sigma = samples['beta'].std(axis=0).squeeze()
plt.figure(figsize=(8,4))
beta_plot = plt.subplot(111)
beta_plot.set_xlabel('dimension')
beta_plot.set_ylabel('beta')
beta_plot.plot(beta, 'gx')
beta_plot.plot(beta + 2*sigma, 'b_');
beta_plot.plot(beta - 2*sigma, 'b_');
beta_plot.plot([0,D],[1,1],'k--', alpha=0.1)
beta_plot.plot([0,D],[0,0],'k--', alpha=0.1)
beta_plot.plot([0,D],[-1,-1],'k--', alpha=0.1);

# %%
samples['beta'].std(axis=0).mean()
# Out:
# 0.14016660937419181
